# %% [markdown]
# # PyCity Schools Analysis

# %% [markdown]
# ### Note
# * Instructions have been included for each segment. You do not have to follow them exactly, but they are included to help you think through the steps.

# %%
# Dependencies and Setup
import pandas as pd
from pandas import DataFrame

school_data_to_load = pd.read_csv('C:\\Users\\bethf\\Desktop\\Resources\\schools.csv')
student_data_to_load = pd.read_csv('C:\\Users\\bethf\\Desktop\\Resources\\students.csv')

# Read School and Student Data File and store into Pandas Data Frames
school_data = (school_data_to_load)
student_data = (student_data_to_load)

# Combine the data into a single dataset
schooldatacomplete = pd.merge(student_data, school_data, how="left", on=["school_name", "school_name"])

schooldatacomplete = schooldatacomplete.rename(columns={"school_name": "School Name","type":"Type"})

schooldatacomplete.head()
# Out:
#    Student ID       student_name gender grade        School Name  \
# 0           0       Paul Bradley      M   9th  Huang High School
# 1           1       Victor Smith      M  12th  Huang High School
# 2           2    Kevin Rodriguez      M  12th  Huang High School
# 3           3  Dr. Richard Scott      M  12th  Huang High School
# 4           4         Bonnie Ray      F   9th  Huang High School
#
#    reading_score  math_score  School ID      Type  size   budget
# 0             66          79          0  District  2917  1910635
# 1             94          61          0  District  2917  1910635
# 2             90          60          0  District  2917  1910635
# 3             67          58          0  District  2917  1910635
# 4             97          84          0  District  2917  1910635

# %% [markdown]
# ## District Summary

# %%
#Calculations to find values for dataframe
totalschools = schooldatacomplete["School Name"].nunique() #Unique school name to get count of schools
totalstudents = schooldatacomplete["Student ID"].nunique() #Unique student IDs to get count of students
totalbudget = school_data["budget"].sum() #Sum of budget for each school
averagemathscore = schooldatacomplete["math_score"].mean() #Average math score for entire district
averagereadingscore = schooldatacomplete["reading_score"].mean() #Average reading score for entire district
#Scores greater than 70 divided by student count to get passing rate for entire district
schoolspassingmath = (schooldatacomplete.loc[schooldatacomplete["math_score"]>=70,"math_score"].count()/totalstudents)*100
schoolspassingreading = (schooldatacomplete.loc[schooldatacomplete["reading_score"]>=70,"reading_score"].count()/totalstudents)*100
schoolspassingoverall = (averagemathscore + averagereadingscore) / 2

#Construct dataframe for values
district_summary_table = DataFrame({"Total Schools":totalschools,\
                                    "Total Students":totalstudents,\
                                    "Total Budget":totalbudget,\
                                    "Average Math Score":averagemathscore,\
                                    "Average Reading Score":averagereadingscore,\
                                    "% Passing Math":schoolspassingmath,\
                                    "% Passing Reading":schoolspassingreading,\
                                    "% Overall Passing Rate":schoolspassingoverall},index=[0])

#Summary table formatting
district_summary_table["Total Students"] = district_summary_table["Total Students"].map("{:,.0f}".format)
district_summary_table["Total Budget"] = district_summary_table["Total Budget"].map("${:,.2f}".format)
district_summary_table["% Passing Math"] = district_summary_table["% Passing Math"].map("{:.2f}%".format)
district_summary_table["% Passing Reading"] = district_summary_table["% Passing Reading"].map("{:.2f}%".format)
district_summary_table["% Overall Passing Rate"] = district_summary_table["% Overall Passing Rate"].map("{:.2f}%".format)

district_summary_table
# Out:
#    Total Schools Total Students    Total Budget  Average Math Score  \
# 0             15         39,170  $24,649,428.00           78.985371
#
#    Average Reading Score % Passing Math % Passing Reading  \
# 0               81.87784         74.98%            85.81%
#
#   % Overall Passing Rate
# 0                 80.43%

# %% [markdown]
# ## School Summary

# %%
#Above caluculations grouped by school
studentsperschool = schooldatacomplete.groupby(["School Name","Type"])["Student ID"].count()
schoolbudget = schooldatacomplete.groupby(["School Name","Type"])["budget"].max()
mathpassingper = schooldatacomplete[schooldatacomplete["math_score"]>=70].groupby("School Name")["Student ID"].count()/studentsperschool*100
readingpassingper = schooldatacomplete[schooldatacomplete["reading_score"]>=70].groupby("School Name")["Student ID"].count()/studentsperschool*100

school_summary = DataFrame({"Total Students":studentsperschool,\
                            "Total School Budget":schoolbudget,\
                            "Per Student Budget":schoolbudget/studentsperschool,\
                            "Average Math Score":schooldatacomplete.groupby(["School Name","Type"])["math_score"].mean(),\
                            "Average Reading Score":schooldatacomplete.groupby(["School Name","Type"])["reading_score"].mean(),\
                            "% Passing Math":mathpassingper,\
                            "% Passing Reading":readingpassingper,\
                            "% Overall Passing Rate":(mathpassingper + readingpassingper)/2})

#Summary table formatting
school_summary["Total School Budget"] = school_summary["Total School Budget"].map("${:,.2f}".format)

school_summary
# Out:
#                                 Total Students Total School Budget  \
# School Name           Type
# Bailey High School    District            4976       $3,124,928.00
# Cabrera High School   Charter             1858       $1,081,356.00
# Figueroa High School  District            2949       $1,884,411.00
# Ford High School      District            2739       $1,763,916.00
# Griffin High School   Charter             1468         $917,500.00
# Hernandez High School District            4635       $3,022,020.00
# Holden High School    Charter              427         $248,087.00
# Huang High School     District            2917       $1,910,635.00
# Johnson High School   District            4761       $3,094,650.00
# Pena High School      Charter              962         $585,858.00
# Rodriguez High School District            3999       $2,547,363.00
# Shelton High School   Charter             1761       $1,056,600.00
# Thomas High School    Charter             1635       $1,043,130.00
# Wilson High School    Charter             2283       $1,319,574.00
# Wright High School    Charter             1800       $1,049,400.00
#
#                                 Per Student Budget  Average Math Score  \
# School Name           Type
# Bailey High School    District               628.0           77.048432
# Cabrera High School   Charter                582.0           83.061895
# Figueroa High School  District               639.0           76.711767
# Ford High School      District               644.0           77.102592
# Griffin High School   Charter                625.0           83.351499
# Hernandez High School District               652.0           77.289752
# Holden High School    Charter                581.0           83.803279
# Huang High School     District               655.0           76.629414
# Johnson High School   District               650.0           77.072464
# Pena High School      Charter                609.0           83.839917
# Rodriguez High School District               637.0           76.842711
# Shelton High School   Charter                600.0           83.359455
# Thomas High School    Charter                638.0           83.418349
# Wilson High School    Charter                578.0           83.274201
# Wright High School    Charter                583.0           83.682222
#
#                                 Average Reading Score  % Passing Math  \
# School Name           Type
# Bailey High School    District              81.033963       66.680064
# Cabrera High School   Charter               83.975780       94.133477
# Figueroa High School  District              81.158020       65.988471
# Ford High School      District              80.746258       68.309602
# Griffin High School   Charter               83.816757       93.392371
# Hernandez High School District              80.934412       66.752967
# Holden High School    Charter               83.814988       92.505855
# Huang High School     District              81.182722       65.683922
# Johnson High School   District              80.966394       66.057551
# Pena High School      Charter               84.044699       94.594595
# Rodriguez High School District              80.744686       66.366592
# Shelton High School   Charter               83.725724       93.867121
# Thomas High School    Charter               83.848930       93.272171
# Wilson High School    Charter               83.989488       93.867718
# Wright High School    Charter               83.955000       93.333333
#
#                                 % Passing Reading  % Overall Passing Rate
# School Name           Type
# Bailey High School    District          81.933280               74.306672
# Cabrera High School   Charter           97.039828               95.586652
# Figueroa High School  District          80.739234               73.363852
# Ford High School      District          79.299014               73.804308
# Griffin High School   Charter           97.138965               95.265668
# Hernandez High School District          80.862999               73.807983
# Holden High School    Charter           96.252927               94.379391
# Huang High School     District          81.316421               73.500171
# Johnson High School   District          81.222432               73.639992
# Pena High School      Charter           95.945946               95.270270
# Rodriguez High School District          80.220055               73.293323
# Figueroa High School  District          80.739234               73.363852
# Rodriguez High School District          80.220055               73.293323

# %% [markdown]
# ## Bottom Performing Schools (By Passing Rate)

# %%
#Above table sorted to show bottom performing schools
bottom_performing_schools = school_summary.sort_values("% Overall Passing Rate")

bottom_performing_schools.head()
# Out:
#                                 Total Students Total School Budget  \
# School Name           Type
# Rodriguez High School District            3999       $2,547,363.00
# Figueroa High School  District            2949       $1,884,411.00
# Huang High School     District            2917       $1,910,635.00
# Johnson High School   District            4761       $3,094,650.00
# Ford High School      District            2739       $1,763,916.00
#
#                                 Per Student Budget  Average Math Score  \
# School Name           Type
# Rodriguez High School District               637.0           76.842711
# Figueroa High School  District               639.0           76.711767
# Huang High School     District               655.0           76.629414
# Johnson High School   District               650.0           77.072464
# Ford High School      District               644.0           77.102592
#
#                                 Average Reading Score  % Passing Math  \
# School Name           Type
# Rodriguez High School District              80.744686       66.366592
# Figueroa High School  District              81.158020       65.988471
# Huang High School     District              81.182722       65.683922
# Johnson High School   District              80.966394       66.057551
# Ford High School      District              80.746258       68.309602
#
#                                 % Passing Reading  % Overall Passing Rate
# School Name           Type
# Rodriguez High School District          80.220055               73.293323
# Figueroa High School  District          80.739234               73.363852
# Huang High School     District          81.316421               73.500171
# Johnson High School   District          81.222432               73.639992
# Ford High School      District          79.299014               73.804308

# %% [markdown]
# ## Math Scores by Grade

# %%
grade9math = schooldatacomplete.loc[schooldatacomplete["grade"]=="9th","grade":"math_score"]
grade10math = schooldatacomplete.loc[schooldatacomplete["grade"]=="10th","grade":"math_score"]
grade11math = schooldatacomplete.loc[schooldatacomplete["grade"]=="11th","grade":"math_score"]
grade12math = schooldatacomplete.loc[schooldatacomplete["grade"]=="12th","grade":"math_score"]

math_scores_by_grade = DataFrame({"9th":grade9math.groupby(["School Name"])["math_score"].mean(),\
                                  "10th":grade10math.groupby(["School Name"])["math_score"].mean(),\
                                  "11th":grade11math.groupby(["School Name"])["math_score"].mean(),\
                                  "12th":grade12math.groupby(["School Name"])["math_score"].mean()})

math_scores_by_grade
# Out:
#                              9th       10th       11th       12th
# School Name
# Bailey High School     77.083676  76.996772  77.515588  76.492218
# Cabrera High School    83.094697  83.154506  82.765560  83.277487
# Figueroa High School   76.403037  76.539974  76.884344  77.151369
# Ford High School       77.361345  77.672316  76.918058  76.179963
# Griffin High School    82.044010  84.229064  83.842105  83.356164
# Hernandez High School  77.438495  77.337408  77.136029  77.186567
# Holden High School     83.787402  83.429825  85.000000  82.855422
# Huang High School      77.027251  75.908735  76.446602  77.225641
# Johnson High School    77.187857  76.691117  77.491653  76.863248
# Pena High School       83.625455  83.372000  84.328125  84.121547
# Rodriguez High School  76.859966  76.612500  76.395626  77.690748
# Shelton High School    83.420755  82.917411  83.383495  83.778976
# Thomas High School     83.590022  83.087886  83.498795  83.497041
# Wilson High School     83.085578  83.724422  83.195326  83.035794
# Wright High School     83.264706  84.010288  83.836782  83.644986

# %% [markdown]
# ## Reading Score by Grade

# %%
grade9reading = schooldatacomplete.loc[schooldatacomplete["grade"]=="9th","grade":"reading_score"]
grade10reading = schooldatacomplete.loc[schooldatacomplete["grade"]=="10th","grade":"reading_score"]
grade11reading = schooldatacomplete.loc[schooldatacomplete["grade"]=="11th","grade":"reading_score"]
grade12reading = schooldatacomplete.loc[schooldatacomplete["grade"]=="12th","grade":"reading_score"]

reading_scores_by_grade = DataFrame({"9th":grade9reading.groupby(["School Name"])["reading_score"].mean(),\
                                  "10th":grade10reading.groupby(["School Name"])["reading_score"].mean(),\
                                  "11th":grade11reading.groupby(["School Name"])["reading_score"].mean(),\
                                  "12th":grade12reading.groupby(["School Name"])["reading_score"].mean()})

reading_scores_by_grade.head(15)
# Out:
#                              9th       10th       11th       12th
# School Name
# Bailey High School     81.303155  80.907183  80.945643  80.912451
# Cabrera High School    83.676136  84.253219  83.788382  84.287958
# Figueroa High School   81.198598  81.408912  80.640339  81.384863
# Ford High School       80.632653  81.262712  80.403642  80.662338
# Griffin High School    83.369193  83.706897  84.288089  84.013699
# Hernandez High School  80.866860  80.660147  81.396140  80.857143
# Holden High School     83.677165  83.324561  83.815534  84.698795
# Huang High School      81.290284  81.512386  81.417476  80.305983
# Johnson High School    81.260714  80.773431  80.616027  81.227564
# Pena High School       83.807273  83.612000  84.335938  84.591160
# Rodriguez High School  80.993127  80.629808  80.864811  80.376426
# Shelton High School    84.122642  83.441964  84.373786  82.781671
# Thomas High School     83.728850  84.254157  83.585542  83.831361
# Wilson High School     83.939778  84.021452  83.764608  84.317673
# Wright High School     83.833333  83.812757  84.156322  84.073171

# %% [markdown]
# ## Scores by School Spending

# %%
spending_bins = [0, 585, 615, 645, 675]
group_labels = ["<$585", "$585-615", "$615-645", "$645-675"]

top_performing_schools["School Spending"] = pd.cut(top_performing_schools["Per Student Budget"], spending_bins, labels=group_labels)

scores_by_school_spending_summary_table = DataFrame({"Average Math Score":top_performing_schools.groupby("School Spending")["Average Math Score"].mean(),\
                                                    "Average Reading Score":top_performing_schools.groupby("School Spending")["Average Reading Score"].mean(),\
                                                    "% Passing Math":top_performing_schools.groupby("School Spending")["% Passing Math"].mean(),\
                                                    "% Passing Reading":top_performing_schools.groupby("School Spending")["% Passing Reading"].mean(),\
                                                    "% Overall Passing Rate":top_performing_schools.groupby("School Spending")["% Overall Passing Rate"].mean()})

scores_by_school_spending_summary_table
# Out:
#                  Average Math Score  Average Reading Score  % Passing Math  \
# School Spending
# <$585                     83.455399              83.933814       93.460096
# $585-615                  83.599686              83.885211       94.230858
# $615-645                  79.079225              81.891436       75.668212
# $645-675                  76.997210              81.027843       66.164813
#
#                  % Passing Reading  % Overall Passing Rate
# School Spending
# <$585                    96.610877               95.035486
# $585-615                 95.900287               95.065572
# $615-645                 86.106569               80.887391
# $645-675                 81.133951               73.649382

# %% [markdown]
# ## Scores by School Size

# %%
size_bins = [0, 1000, 2000, 5000]
group_names = ["Small (<1000)", "Medium (1000-2000)", "Large (2000-5000)"]

top_performing_schools["School Size"] = pd.cut(top_performing_schools["Total Students"], size_bins, labels=group_names)

scores_by_school_size_summary_table = DataFrame({"Average Math Score":top_performing_schools.groupby("School Size")["Average Math Score"].mean(),\
                                                    "Average Reading Score":top_performing_schools.groupby("School Size")["Average Reading Score"].mean(),\
                                                    "% Passing Math":top_performing_schools.groupby("School Size")["% Passing Math"].mean(),\
                                                    "% Passing Reading":top_performing_schools.groupby("School Size")["% Passing Reading"].mean(),\
                                                    "% Overall Passing Rate":top_performing_schools.groupby("School Size")["% Overall Passing Rate"].mean()})
scores_by_school_size_summary_table
# Out:
#                     Average Math Score  Average Reading Score  % Passing Math  \
# School Size
# Small (<1000)                83.821598              83.929843       93.550225
# Medium (1000-2000)           83.374684              83.864438       93.599695
# Large (2000-5000)            77.746417              81.344493       69.963361
#
#                     % Passing Reading  % Overall Passing Rate
# School Size
# Small (<1000)               96.099437               94.824831
# Medium (1000-2000)          96.790680               95.195187
# Large (2000-5000)           82.766634               76.364998

# %% [markdown]
# ## Scores by School Type

# %%
scores_by_school_type_summary_table = DataFrame({"Average Math Score":top_performing_schools.groupby("Type")["Average Math Score"].mean(),\
                                                    "Average Reading Score":top_performing_schools.groupby("Type")["Average Reading Score"].mean(),\
                                                    "% Passing Math":top_performing_schools.groupby("Type")["% Passing Math"].mean(),\
                                                    "% Passing Reading":top_performing_schools.groupby("Type")["% Passing Reading"].mean(),\
                                                    "% Overall Passing Rate":top_performing_schools.groupby("Type")["% Overall Passing Rate"].mean()})
scores_by_school_type_summary_table
# Out:
#           Average Math Score  Average Reading Score  % Passing Math  \
# Type
# Charter            83.473852              83.896421       93.620830
# District           76.956733              80.966636       66.548453
#
#           % Passing Reading  % Overall Passing Rate
# Type
# Charter           96.586489               95.103660
# District          80.799062               73.673757
