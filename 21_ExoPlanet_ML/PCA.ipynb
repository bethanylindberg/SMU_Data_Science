# %%
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt
# %matplotlib inline
df = pd.read_csv("cumulative.csv")
df = df.drop(columns=["rowid", "kepid", "kepoi_name", "kepler_name", "koi_pdisposition", "koi_score", "koi_tce_delivname"])
# Drop the null columns where all values are null
df
df = df.dropna(axis='columns', how='all')
# Drop the null rows
df = df.dropna()
df.head()
targets = pd.get_dummies(df['koi_disposition'],drop_first=False)

df = pd.concat([df,targets],axis=1)
df.drop(['koi_disposition'],axis=1,inplace=True)
df.head()
# Out:
#    koi_fpflag_nt  koi_fpflag_ss  koi_fpflag_co  koi_fpflag_ec  koi_period  \
# 0              0              0              0              0    9.488036
# 1              0              0              0              0   54.418383
# 2              0              1              0              0   19.899140
# 3              0              1              0              0    1.736952
# 4              0              0              0              0    2.525592
#
#    koi_period_err1  koi_period_err2  koi_time0bk  koi_time0bk_err1  \
# 0     2.775000e-05    -2.775000e-05   170.538750          0.002160
# 1     2.479000e-04    -2.479000e-04   162.513840          0.003520
# 2     1.494000e-05    -1.494000e-05   175.850252          0.000581
# 3     2.630000e-07    -2.630000e-07   170.307565          0.000115
# 4     3.761000e-06    -3.761000e-06   171.595550          0.001130
#
#    koi_time0bk_err2  ...  koi_slogg_err2  koi_srad  koi_srad_err1  \
# 0         -0.002160  ...          -0.096     0.927          0.105
# 1         -0.003520  ...          -0.096     0.927          0.105
# 2         -0.000581  ...          -0.176     0.868          0.233
# 3         -0.000115  ...          -0.168     0.791          0.201
# 4         -0.001130  ...          -0.210     1.046          0.334
#
#    koi_srad_err2         ra        dec  koi_kepmag  CANDIDATE  CONFIRMED  \
# 0         -0.061  291.93423  48.141651      15.347          0          1
# 1         -0.061  291.93423  48.141651      15.347          0          1
# 2         -0.078  297.00482  48.134129      15.436          0          0
# 3         -0.067  285.53461  48.285210      15.597          0          0
# 4         -0.133  288.75488  48.226200      15.509          0          1
#
#    FALSE POSITIVE
# 0               0
# 1               0
# 2               1
# 3               1
# 4               0
#
# [5 rows x 43 columns]

# %%
from sklearn.preprocessing import StandardScaler
scaler = StandardScaler()

target = df["CANDIDATE"]
data = df.drop("CANDIDATE",axis=1)
scaler.fit(data)
scaled_data = scaler.transform(data)
# PCA
from sklearn.decomposition import PCA
pca = PCA(n_components=2)
pca.fit(scaled_data)
x_pca = pca.transform(scaled_data)
plt.figure(figsize=(8,6))
plt.scatter(x_pca[:,0],x_pca[:,1],c=target,cmap="plasma")
# Out:
# C:\Users\bethf\Anaconda3\lib\site-packages\sklearn\preprocessing\data.py:645: DataConversionWarning: Data with input dtype uint8, int64, float64 were all converted to float64 by StandardScaler.
#   return self.partial_fit(X, y)
# C:\Users\bethf\Anaconda3\lib\site-packages\ipykernel_launcher.py:7: DataConversionWarning: Data with input dtype uint8, int64, float64 were all converted to float64 by StandardScaler.
#   import sys

# %%
from sklearn.preprocessing import StandardScaler
scaler = StandardScaler()

target = df["CONFIRMED"]
data = df.drop("CONFIRMED",axis=1)
scaler.fit(data)
scaled_data = scaler.transform(data)
# PCA
from sklearn.decomposition import PCA
pca = PCA(n_components=2)
pca.fit(scaled_data)
x_pca = pca.transform(scaled_data)
plt.figure(figsize=(8,6))
plt.scatter(x_pca[:,0],x_pca[:,1],c=target,cmap="plasma")
# Out:
# C:\Users\bethf\Anaconda3\lib\site-packages\sklearn\preprocessing\data.py:645: DataConversionWarning: Data with input dtype uint8, int64, float64 were all converted to float64 by StandardScaler.
#   return self.partial_fit(X, y)
# C:\Users\bethf\Anaconda3\lib\site-packages\ipykernel_launcher.py:7: DataConversionWarning: Data with input dtype uint8, int64, float64 were all converted to float64 by StandardScaler.
#   import sys

# %%
from sklearn.preprocessing import StandardScaler
scaler = StandardScaler()

target = df["FALSE POSITIVE"]
data = df.drop("FALSE POSITIVE",axis=1)
scaler.fit(data)
scaled_data = scaler.transform(data)
# PCA
from sklearn.decomposition import PCA
pca = PCA(n_components=2)
pca.fit(scaled_data)
x_pca = pca.transform(scaled_data)
plt.figure(figsize=(8,6))
plt.scatter(x_pca[:,0],x_pca[:,1],c=target,cmap="plasma")
# Out:
# C:\Users\bethf\Anaconda3\lib\site-packages\sklearn\preprocessing\data.py:645: DataConversionWarning: Data with input dtype uint8, int64, float64 were all converted to float64 by StandardScaler.
#   return self.partial_fit(X, y)
# C:\Users\bethf\Anaconda3\lib\site-packages\ipykernel_launcher.py:7: DataConversionWarning: Data with input dtype uint8, int64, float64 were all converted to float64 by StandardScaler.
#   import sys

# %%
df = df.dropna(axis='columns', how='all')
# Drop the null rows
df = df.dropna()
Dummies = pd.get_dummies(df)

corr = Dummies.corr()
corr.style.background_gradient(cmap='coolwarm')
# Out:
# <style  type="text/css" >
#     #T_a2b69b8a_a6fa_11e9_90ee_645d863cc5derow0_col0 {
#             background-color:  #b40426;
#             color:  #f1f1f1;
#         }    #T_a2b69b8a_a6fa_11e9_90ee_645d863cc5derow0_col1 {
#             background-color:  #4c66d6;
#             color:  #000000;
#         }    #T_a2b69b8a_a6fa_11e9_90ee_645d863cc5derow0_col2 {
#             background-color:  #85a8fc;
#             color:  #000000;
#         }    #T_a2b69b8a_a6fa_11e9_90ee_645d863cc5derow0_col3 {
#             background-color:  #85a8fc;
#             color:  #000000;
#         }    #T_a2b69b8a_a6fa_11e9_90ee_645d863cc5derow0_col4 {
#             background-color:  #f6bfa6;
#             color:  #000000;
#         }    #T_a2b69b8a_a6fa_11e9_90ee_645d863cc5derow0_col5 {
#             background-color:  #f7b79b;
#             color:  #000000;
#         }    #T_a2b69b8a_a6fa_11e9_90ee_645d863cc5derow0_col6 {
#             background-color:  #a9c6fd;
#             color:  #000000;
#         }    #T_a2b69b8a_a6fa_11e9_90ee_645d863cc5derow0_col7 {
#             background-color:  #d8dce2;
#             color:  #000000;
#         }    #T_a2b69b8a_a6fa_11e9_90ee_645d863cc5derow0_col8 {
#             background-color:  #f4c6af;
#             color:  #000000;
#         }    #T_a2b69b8a_a6fa_11e9_90ee_645d863cc5derow0_col9 {
#             background-color:  #bad0f8;
#             color:  #000000;
#         }    #T_a2b69b8a_a6fa_11e9_90ee_645d863cc5derow0_col10 {
#             background-color:  #d8dce2;
#             color:  #000000;
#         }    #T_a2b69b8a_a6fa_11e9_90ee_645d863cc5derow0_col11 {
#             background-color:  #6c8ff1;
#             color:  #000000;
#         }    #T_a2b69b8a_a6fa_11e9_90ee_645d863cc5derow0_col12 {
#             background-color:  #c5d6f2;
#             color:  #000000;
#         }    #T_a2b69b8a_a6fa_11e9_90ee_645d863cc5derow0_col13 {
#             background-color:  #d5dbe5;
#             color:  #000000;
#         }    #T_a2b69b8a_a6fa_11e9_90ee_645d863cc5derow0_col14 {
#             background-color:  #f7b599;
#             color:  #000000;
#         }    #T_a2b69b8a_a6fa_11e9_90ee_645d863cc5derow0_col15 {
#             background-color:  #a7c5fe;
#             color:  #000000;
#         }    #T_a2b69b8a_a6fa_11e9_90ee_645d863cc5derow0_col16 {
#             background-color:  #6c8ff1;
#             color:  #000000;
#         }    #T_a2b69b8a_a6fa_11e9_90ee_645d863cc5derow0_col17 {
#             background-color:  #e0dbd8;
#             color:  #000000;
#         }    #T_a2b69b8a_a6fa_11e9_90ee_645d863cc5derow0_col18 {
#             background-color:  #d9dce1;
#             color:  #000000;
#         }    #T_a2b69b8a_a6fa_11e9_90ee_645d863cc5derow0_col19 {
#             background-color:  #e2dad5;
#             color:  #000000;
#         }    #T_a2b69b8a_a6fa_11e9_90ee_645d863cc5derow0_col20 {
#             background-color:  #cad8ef;
#             color:  #000000;
#         }    #T_a2b69b8a_a6fa_11e9_90ee_645d863cc5derow0_col21 {
#             background-color:  #d6dce4;
#             color:  #000000;
#         }    #T_a2b69b8a_a6fa_11e9_90ee_645d863cc5derow0_col22 {
#             background-color:  #abc8fd;
#             color:  #000000;
#         }    #T_a2b69b8a_a6fa_11e9_90ee_645d863cc5derow0_col23 {
#             background-color:  #dadce0;
#             color:  #000000;
#         }    #T_a2b69b8a_a6fa_11e9_90ee_645d863cc5derow0_col24 {
#             background-color:  #d6dce4;
#             color:  #000000;
#         }    #T_a2b69b8a_a6fa_11e9_90ee_645d863cc5derow0_col25 {
#             background-color:  #dadce0;
#             color:  #000000;
#         }    #T_a2b69b8a_a6fa_11e9_90ee_645d863cc5derow0_col26 {
#             background-color:  #4f69d9;
#             color:  #000000;
#         }    #T_a2b69b8a_a6fa_11e9_90ee_645d863cc5derow0_col27 {
#             background-color:  #799cf8;
#             color:  #000000;
#         }    #T_a2b69b8a_a6fa_11e9_90ee_645d863cc5derow0_col28 {
#             background-color:  #cbd8ee;
#             color:  #000000;
#         }    #T_a2b69b8a_a6fa_11e9_90ee_645d863cc5derow0_col29 {
#             background-color:  #e2dad5;
#             color:  #000000;
#         }    #T_a2b69b8a_a6fa_11e9_90ee_645d863cc5derow0_col30 {
#             background-color:  #b7cff9;
#             color:  #000000;
#         }    #T_a2b69b8a_a6fa_11e9_90ee_645d863cc5derow0_col31 {
#             background-color:  #a3c2fe;
#             color:  #000000;
#         }    #T_a2b69b8a_a6fa_11e9_90ee_645d863cc5derow0_col32 {
#             background-color:  #b6cefa;
#             color:  #000000;
#         }    #T_a2b69b8a_a6fa_11e9_90ee_645d863cc5derow0_col33 {
#             background-color:  #80a3fa;
#             color:  #000000;
#         }    #T_a2b69b8a_a6fa_11e9_90ee_645d863cc5derow0_col34 {
#             background-color:  #d9dce1;
#             color:  #000000;
#         }    #T_a2b69b8a_a6fa_11e9_90ee_645d863cc5derow0_col35 {
#             background-color:  #d3dbe7;
#             color:  #000000;
#         }    #T_a2b69b8a_a6fa_11e9_90ee_645d863cc5derow0_col36 {
#             background-color:  #c9d7f0;
#             color:  #000000;
#         }    #T_a2b69b8a_a6fa_11e9_90ee_645d863cc5derow0_col37 {
#             background-color:  #6485ec;
#             color:  #000000;
#         }    #T_a2b69b8a_a6fa_11e9_90ee_645d863cc5derow0_col38 {
#             background-color:  #4a63d3;
#             color:  #f1f1f1;
#         }    #T_a2b69b8a_a6fa_11e9_90ee_645d863cc5derow0_col39 {
#             background-color:  #7597f6;
#             color:  #000000;
#         }    #T_a2b69b8a_a6fa_11e9_90ee_645d863cc5derow0_col40 {
#             background-color:  #7da0f9;
#             color:  #000000;
#         }    #T_a2b69b8a_a6fa_11e9_90ee_645d863cc5derow0_col41 {
#             background-color:  #82a6fb;
#             color:  #000000;
#         }    #T_a2b69b8a_a6fa_11e9_90ee_645d863cc5derow0_col42 {
#             background-color:  #f5c1a9;
#             color:  #000000;
#         }    #T_a2b69b8a_a6fa_11e9_90ee_645d863cc5derow1_col0 {
#             background-color:  #536edd;
#             color:  #000000;
#         }    #T_a2b69b8a_a6fa_11e9_90ee_645d863cc5derow1_col1 {
#             background-color:  #b40426;
#             color:  #f1f1f1;
#         }    #T_a2b69b8a_a6fa_11e9_90ee_645d863cc5derow1_col2 {
#             background-color:  #abc8fd;
#             color:  #000000;
#         }    #T_a2b69b8a_a6fa_11e9_90ee_645d863cc5derow1_col3 {
#             background-color:  #90b2fe;
#             color:  #000000;
#         }    #T_a2b69b8a_a6fa_11e9_90ee_645d863cc5derow1_col4 {
#             background-color:  #a1c0ff;
#             color:  #000000;
#         }    #T_a2b69b8a_a6fa_11e9_90ee_645d863cc5derow1_col5 {
#             background-color:  #cbd8ee;
#             color:  #000000;
#         }    #T_a2b69b8a_a6fa_11e9_90ee_645d863cc5derow1_col6 {
#             background-color:  #ecd3c5;
#             color:  #000000;
#         }    #T_a2b69b8a_a6fa_11e9_90ee_645d863cc5derow1_col7 {
#             background-color:  #88abfd;
#             color:  #000000;
#         }    #T_a2b69b8a_a6fa_11e9_90ee_645d863cc5derow1_col8 {
#             background-color:  #c5d6f2;
#             color:  #000000;
#         }    #T_a2b69b8a_a6fa_11e9_90ee_645d863cc5derow1_col9 {
#             background-color:  #efcebd;
#             color:  #000000;
#         }    #T_a2b69b8a_a6fa_11e9_90ee_645d863cc5derow1_col10 {
#             background-color:  #d5dbe5;
#             color:  #000000;
#         }    #T_a2b69b8a_a6fa_11e9_90ee_645d863cc5derow1_col11 {
#             background-color:  #9bbcff;
#             color:  #000000;
#         }    #T_a2b69b8a_a6fa_11e9_90ee_645d863cc5derow1_col12 {
#             background-color:  #d6dce4;
#             color:  #000000;
#         }    #T_a2b69b8a_a6fa_11e9_90ee_645d863cc5derow1_col13 {
#             background-color:  #98b9ff;
#             color:  #000000;
#         }    #T_a2b69b8a_a6fa_11e9_90ee_645d863cc5derow1_col14 {
#             background-color:  #c3d5f4;
#             color:  #000000;
#         }    #T_a2b69b8a_a6fa_11e9_90ee_645d863cc5derow1_col15 {
#             background-color:  #f1cdba;
#             color:  #000000;
#         }    #T_a2b69b8a_a6fa_11e9_90ee_645d863cc5derow1_col16 {
#             background-color:  #
